# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Final Project

# %% [markdown]
# # Introduction
# This notebook contains exercises demonstrating basic Markdown and Python skills for data science. It covers data science languages, libraries, tools, and simple arithmetic operations.

# %% [markdown]
# ## Data Science Languages Some common languages used in Data Science are: -
# - Python
# - R
# - SQL
# - Java
# - Julia
# - Scala

# %%
## Data Science Libraries Popular libraries used in data science include: - NumPy - Pandas - Matplotlib- Scikit-learn - TensorFlow- PyTorch

# %% [markdown]
# ## Data Science Tools
# | Tool          | Description |
# |--------------|------------|
# | Jupyter Notebook  Interactive computing environment |
# | RStudio      | IDE for R programming |
# | TensorFlow   | Machine learning framework |
# | Apache Spark | Big data processing |
# | Tableau      | Data visualization tool |

# %% [markdown]
# ## Arithmetic Expressions Examples of arithmetic operations in Python:
# Addition: 2 + 3 = 5
# Multiplication: 4 * 5 = 20
# Division: 10 / 2 = 5.0

# %% [markdown]
# # Multiply and add two numbers
# num1 = 5
# num2 = 10
# result = (num1 * num2) + 20
# print("Result:", result)

# %% [markdown]
# # Convert minutes to hours
# minutes = 120
# hours = minutes / 60
# print(f"{minutes} minutes is equal to {hours} hours.")

# %% [markdown]
# ## Objectives
# - List data science languages and libraries.
# - Provide a table of data science tools.
# - Demonstrate basic arithmetic operations in Python.
# - Perform simple mathematical computations using code.

# %% [markdown]
# ## Author
# Zohra Khwaja
